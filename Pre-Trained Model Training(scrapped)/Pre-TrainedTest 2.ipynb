# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import pathlib
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# %%
pre_trained_model = MobileNetV2(include_top=False, pooling='avg')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
pre_trained_model.trainable = False

# %%
train_data_location = 'C:/Users/danie/Documents/FTDS/Capstone/3. Model/Data/Train'
train_data = ImageDataGenerator(preprocessing_function = preprocess_input).flow_from_directory(train_data_location, target_size=(224,224))
# Out:
# Found 5528 images belonging to 12 classes.

# %%
validation_data_location = 'C:/Users/danie/Documents/FTDS/Capstone/3. Model/Data/Test'
validation_data = ImageDataGenerator(preprocessing_function = preprocess_input).flow_from_directory(validation_data_location, target_size=(224,224))
# Out:
# Found 1303 images belonging to 12 classes.

# %%
class_mappings = train_data.class_indices
print(class_mappings)
# Out:
# {'Blouses': 0, 'Dresses': 1, 'Jackets & Coats': 2, 'Jeans': 3, 'Jumpers': 4, 'Polos': 5, 'Shirts': 6, 'Shorts': 7, 'Skirts': 8, 'Suits': 9, 'T-Shirts': 10, 'Trousers': 11}

# %%
model = Sequential()
model.add(pre_trained_model)
model.add(Dense(len(class_mappings), activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(class_mappings), activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'])#add more metrics if req

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 1280)              2257984
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                15372
# _________________________________________________________________
# dropout (Dropout)            (None, 12)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                156
# =================================================================
# Total params: 2,273,512
# Trainable params: 15,528
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
training_history = model.fit(train_data, epochs=20, validation_data=validation_data)
# Out:
# Epoch 1/20
# 173/173 [==============================] - 638s 4s/step - loss: 1.8705 - accuracy: 0.3730 - val_loss: 1.4813 - val_accuracy: 0.5495
# Epoch 2/20
# 173/173 [==============================] - 571s 3s/step - loss: 1.5028 - accuracy: 0.4937 - val_loss: 1.2576 - val_accuracy: 0.6239
# Epoch 3/20
# 173/173 [==============================] - 576s 3s/step - loss: 1.3367 - accuracy: 0.5445 - val_loss: 1.1382 - val_accuracy: 0.6393
# Epoch 4/20
# 173/173 [==============================] - 605s 3s/step - loss: 1.2460 - accuracy: 0.5725 - val_loss: 1.0924 - val_accuracy: 0.6347
# Epoch 5/20
# 173/173 [==============================] - 528s 3s/step - loss: 1.1722 - accuracy: 0.5917 - val_loss: 1.0442 - val_accuracy: 0.6738
# Epoch 6/20
# 173/173 [==============================] - 518s 3s/step - loss: 1.1495 - accuracy: 0.5932 - val_loss: 1.0218 - val_accuracy: 0.6616
# Epoch 7/20
# 173/173 [==============================] - 491s 3s/step - loss: 1.1040 - accuracy: 0.6080 - val_loss: 0.9799 - val_accuracy: 0.6838
# Epoch 8/20
# 173/173 [==============================] - 527s 3s/step - loss: 1.0654 - accuracy: 0.6257 - val_loss: 0.9688 - val_accuracy: 0.6708
# Epoch 9/20
# 173/173 [==============================] - 486s 3s/step - loss: 1.0369 - accuracy: 0.6360 - val_loss: 0.9750 - val_accuracy: 0.6853
# Epoch 10/20
# 173/173 [==============================] - 492s 3s/step - loss: 1.0212 - accuracy: 0.6393 - val_loss: 0.9445 - val_accuracy: 0.6846
# Epoch 11/20
# 173/173 [==============================] - 26317s 152s/step - loss: 0.9767 - accuracy: 0.6500 - val_loss: 0.9346 - val_accuracy: 0.6907
# Epoch 12/20
# 173/173 [==============================] - 533s 3s/step - loss: 0.9571 - accuracy: 0.6577 - val_loss: 0.9354 - val_accuracy: 0.6984
# Epoch 13/20
# 173/173 [==============================] - 643s 4s/step - loss: 0.9482 - accuracy: 0.6677 - val_loss: 0.9316 - val_accuracy: 0.6915
# Epoch 14/20
# 173/173 [==============================] - 571s 3s/step - loss: 0.9244 - accuracy: 0.6719 - val_loss: 0.9197 - val_accuracy: 0.6907
# Epoch 15/20
# 173/173 [==============================] - 568s 3s/step - loss: 0.9068 - accuracy: 0.6762 - val_loss: 0.9273 - val_accuracy: 0.6815
# Epoch 16/20
# 173/173 [==============================] - 500s 3s/step - loss: 0.9045 - accuracy: 0.6811 - val_loss: 0.9206 - val_accuracy: 0.6961
# Epoch 17/20
# 173/173 [==============================] - 368s 2s/step - loss: 0.8887 - accuracy: 0.6822 - val_loss: 0.9125 - val_accuracy: 0.6992
# Epoch 18/20
# 173/173 [==============================] - 355s 2s/step - loss: 0.8647 - accuracy: 0.6901 - val_loss: 0.9079 - val_accuracy: 0.6961
# Epoch 19/20
# 173/173 [==============================] - 352s 2s/step - loss: 0.8274 - accuracy: 0.7057 - val_loss: 0.9149 - val_accuracy: 0.7045
# Epoch 20/20
# 173/173 [==============================] - 384s 2s/step - loss: 0.8492 - accuracy: 0.6950 - val_loss: 0.9340 - val_accuracy: 0.7015

# %%
# Save Model
fer_json = model.to_json()
with open("model2.json", "w") as json_file:
    json_file.write(fer_json)
model.save_weights("model2.h5")

# %%
def plot_training_accuracy(training_history):
    plt.plot(training_history.history['accuracy'], label = 'training accuracy')
    plt.plot(training_history.history['val_accuracy'], label = 'validation accuracy')
    plt.legend
    plt.xlabel('epoch')
    plt.ylabel('accuracy')

def plot_training_loss(training_history):
    plt.plot(training_history.history['loss'], label = 'training loss')
    plt.plot(training_history.history['val_loss'], label = 'validation loss')
    plt.legend
    plt.xlabel('epoch')
    plt.ylabel('loss')

# %%
plot_training_accuracy(training_history)

# %%
plot_training_loss(training_history)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import numpy as np
from keras.models import model_from_json

# %%
train_data.class_indices
# Out:
# {'Blouses': 0,
#  'Dresses': 1,
#  'Jackets & Coats': 2,
#  'Jeans': 3,
#  'Jumpers': 4,
#  'Polos': 5,
#  'Shirts': 6,
#  'Shorts': 7,
#  'Skirts': 8,
#  'Suits': 9,
#  'T-Shirts': 10,
#  'Trousers': 11}

# %%
# Load Model
alessandra = model_from_json(open("model.json", "r").read()) 
alessandra.load_weights('model.h5')

# %%
sartorial = image.load_img("./Data/Dress1.jpg", target_size=(224, 224))
sartorial = image.img_to_array(sartorial)
sartorial =np.expand_dims(sartorial ,axis=0)
imgplot = plt.imshow(sartorial)
print(sartorial.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-8dfa06aa084d> in <module>
#       2 sartorial = image.img_to_array(sartorial)
#       3 sartorial =np.expand_dims(sartorial ,axis=0)
# ----> 4 imgplot = plt.imshow(sartorial)
#       5 print(sartorial.shape)
#
# ~\anaconda3\envs\FTDS\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\FTDS\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\FTDS\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~\anaconda3\envs\FTDS\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     707         if not (self._A.ndim == 2
#     708                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 709             raise TypeError("Invalid shape {} for image data"
#     710                             .format(self._A.shape))
#     711
#
# TypeError: Invalid shape (1, 224, 224, 3) for image data

# %%
sartorial = pre_process_input(sartorial)

# %%
predictions = model.predict(sartorial)
predicted_class = np.argmax(predictions)
print(predicted_class)

# %%
#from imagenet class predictor
print("Top predictions for this image:")

for imagenet_id, name, likelihood in predicted_classes[0]:
    print(f"Prediction: {name} - {likelihood:2f}")
