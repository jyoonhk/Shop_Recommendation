# %%
import pandas as pd
import glob
os.chdir("../FindTheCulprit")
import re
import matplotlib.pyplot as plt

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "Four.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("Four.csv")

# %%
df['Category'].value_counts()
# Out:
# Accessories        1219
# T-Shirts           1216
# Jumpers            1047
# Trousers            957
# Jackets & Coats     724
# Shorts              452
# Polos               412
# Shoes               368
# Shirts              362
# Dresses             333
# Jeans               320
# Skirts              224
# Suits               206
# Tops                171
# Blouses             143
# Tracksuits           55
# Jumpsuits            33
# Knitwear             32
# Other                22
# Leggings             11
# Name: Category, dtype: int64

# %%
df.loc[df.Category == "Jumpsuits", "Category"] = "Dresses"
df.loc[df.Category == "Knitwear", "Category"] = "Jumpers"
df.loc[df.Category == "Tops", "Category"] = "Blouses"
df.loc[df.Gender == "Men", "Gender"] = "Mens"
df.loc[df.Gender == "Women", "Gender"] = "Womens"

df = df[df.Category != 'Accessories']
df = df[df.Category != 'Shoes']
df = df[df.Category != 'Leggings']
df = df[df.Category != 'Other']
df = df[df.Category != 'Tracksuits']

# %%
df['Category'].value_counts()
# Out:
# T-Shirts           1216
# Jumpers            1079
# Trousers            957
# Jackets & Coats     724
# Shorts              452
# Polos               412
# Dresses             366
# Shirts              362
# Jeans               320
# Blouses             314
# Skirts              224
# Suits               206
# Name: Category, dtype: int64

# %%
df.to_csv("AllCombined.csv")

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
